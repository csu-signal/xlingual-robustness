# %%
from WikiCrawler_poolrelaxtar import Crawl
path="/s/red/a/nobackup/cwc-ro/shadim/languages/"

# %%
import os
for lang in ['en','hi','sco','cy','es','ca','cs','sk','id','ms','oc','nl','af','it','ast']:
    if not os.path.isfile(path+lang+"/title_dataset.csv"):
        print(lang)
        cr=Crawl(lang,1000,100000,path,0)
        data=cr.crawl()
# Out:
# en
# WARNING:root:Template errors in article '1-Hexene (data page)' (11952224): title(1) recursion(0, 0, 0)
# WARNING:root:Template errors in article '1-Hexene (data page)' (11952224): title(1) recursion(0, 0, 0)
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# WARNING:root:Template errors in article '1959 in jazz' (25654678): title(1) recursion(0, 0, 0)
# WARNING:root:Template errors in article '1959 in jazz' (25654678): title(1) recursion(0, 0, 0)
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# WARNING:root:Template errors in article '1972 Asian Table Tennis Championships' (63267186): title(2) recursion(0, 0, 0)
# WARNING:root:Template errors in article '1972 Asian Table Tennis Championships' (63267186): title(2) recursion(0, 0, 0)
# ...

# %%
cr=Crawl(lang,1000,100000,path,0)
data=cr.crawl()
# Out:
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000
# 8500
# 9000
# 9500
# 10000
# 10500
# 11000
# 11500
# 12000
# 12500
# 13000
# 13500
# 14000
# 14500
# 15000
# 15500
# 16000
# 16500
# 17000
# 17500
# 18000
# 18500
# 19000
# 19500
# 20000
# 20500
# 21000
# 21500
# 22000
# 22500
# 23000
# 23500
# 24000
# 24500
# 25000
# 25500
# 26000
# 26500
# 27000
# 27500
# 28000
# 28500
# 29000
# 29500
# 30000
# 30500
# 31000
# 31500
# 32000
# 32500
# 33000
# 33500
# 34000
# 34500
# 35000
# 35500
# 36000
# 36500
# 37000
# 37500
# 38000
# 38500
# 39000
# 39500
# 40000
# 40500
# 41000
# 41500
# 42000
# 42500
# 43000
# 43500
# 44000
# 44500
# 45000
# 45500
# 46000
# 46500
# 47000
# 47500
# 48000
# 48500
# 49000
# 49500
# 50000
# 50500
# 51000
# 51500
# 52000
# 52500
# 53000
# 53500
# 54000
# 54500
# 55000
# 55500
# 56000
# 56500
# 57000
# 57500
# 58000
# 58500
# 59000
# 59500
# 60000
# 60500
# 61000
# 61500
# 62000
# 62500
# 63000
# 63500
# ...

# %%
import pandas as pd
all_languages = list(pd.read_csv('../finetuning_BERT_NER/all_languages_pair_3', sep=',', encoding='utf-8')['l1'])

# %%
path="/s/red/a/nobackup/cwc-ro/shadim/languages/"
visited_lang=[]
for lang in all_languages:
    if not lang in visited_lang:
        visited_lang.append(lang)
        pre_dataset = pd.read_csv(path+lang+"/title_dataset.csv", sep=',', encoding='utf-8')
        print(lang+": "+str(len(pre_dataset.index)))
# Out:
# fr: 100001
# br: 8139
# ar: 100001
# fa: 100001
# hi: 42631
# en: 100000
# sco: 5114
# cy: 15233
# es: 100000
# ca: 100001
# cs: 100002
# sk: 61171
# id: 100002
# ms: 60342
# oc: 13781
# nl: 100000
# af: 29661
# it: 100002
# scn: 1427
# an: 5120
# ast: 85501
